# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import optuna
import numpy as np
from sklearn.model_selection import StratifiedKFold, cross_val_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from prettytable import PrettyTable

from sklearn.inspection import permutation_importance
from sklearn.model_selection import cross_val_score
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /opt/conda/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 11.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# /kaggle/input/playground-series-s4e2/sample_submission.csv
# /kaggle/input/playground-series-s4e2/train.csv
# /kaggle/input/playground-series-s4e2/test.csv

# %%
train=pd.read_csv('../input/playground-series-s4e2/train.csv')
test=pd.read_csv('../input/playground-series-s4e2/test.csv')

# %% [markdown]
# * FAVC: Frequent consumption of high caloric food
# * FCVC: Frequency of consumption of vegetables
# * NCP: Number of main meals
# * CAEC: Consumption of food between meals
# * SMOKE: Smoker or not
# * CH2O: Consumption of water daily
# * SCC: Self-Care Commitment
# * FAF: Physical activity frequency
# * TUE: Time using technology devices
# * CALC: Consumption of alcohol
# * MTRANS: Mode of transport
# * NObeyesdad: Different levels of obesity

# %%
# Features to yesno encode:
yesno_encode = ['family_history_with_overweight', 'SMOKE', 'SCC', 'FAVC']

# Features to One-Hot encode: 
oh_encode = ['MTRANS']

# NObeyesdad mapping
NObeyesdad_mapping = {
    'Insufficient_Weight': 0,
    'Normal_Weight': 1,
    'Overweight_Level_I': 2,
    'Overweight_Level_II': 3,
    'Obesity_Type_I': 4,
    'Obesity_Type_II': 5,
    'Obesity_Type_III': 6
}
for column in yesno_encode:
    train[column] = train[column].map({'no': 0, 'yes': 1})
    
train['Gender'] = train['Gender'].map({'Male': 0, 'Female': 1})

train = pd.get_dummies(train, columns=oh_encode, prefix=oh_encode[0])

train = train.drop(['id'], axis=1)

train['CAEC'] = train['CAEC'].map({'no': 0, 'Sometimes': 1, 'Frequently': 2, 'Always': 3})
train['CALC'] = train['CALC'].map({'no': 0, 'Sometimes': 1, 'Frequently': 2})
train['NObeyesdad'] = train['NObeyesdad'].map(NObeyesdad_mapping)
import pandas as pd

min_age = train['Age'].min()
max_age = train['Age'].max()

bins = [min_age-1, 20, 30, 40, max_age+1]

labels = [f'{min_age}-20', '21-30', '31-40', f'41-{max_age}']

# Use pd.cut to categorize 'Age' values with the corrected labels
train['Age_Group'] = pd.cut(train['Age'], bins=bins, labels=labels)

# Apply one-hot encoding to the 'Age_Group' column
train = pd.get_dummies(train, columns=['Age_Group'], prefix='Age')

dummy_columns = [f'Age_{label}' for label in labels]

# train[dummy_columns] = train[dummy_columns].astype(int)
min_weight = train['Weight'].min()
max_weight = train['Weight'].max()

weight_bins = np.linspace(min_weight, max_weight, num=5) 
weight_labels = ['Part 1', 'Part 2', 'Part 3', 'Part 4']
train['Weight_Part'] = pd.cut(train['Weight'], bins=weight_bins, labels=weight_labels, include_lowest=True)

train = pd.get_dummies(train, columns=['Weight_Part'], prefix='Weight')
std_dev_height = train['Height'].std()
mean_height = train['Height'].mean()
# Split height into categories based on standard deviations
bins = [train['Height'].min()] + [mean_height - 2 * std_dev_height] + [mean_height - std_dev_height] + \
       [mean_height + std_dev_height] + [mean_height + 2 * std_dev_height] + [train['Height'].max()]
labels = ['Part 1', 'Part 2', 'Part 3', 'Part 4', 'Part 5']
train['Height_Std_Dev'] = pd.cut(train['Height'], bins=bins, labels=labels, include_lowest=True)

# One-hot encode the Height_Std_Dev feature
train = pd.get_dummies(train, columns=['Height_Std_Dev'], prefix='Height_Std_Dev')
bin_edges = [1, 2, 3.1]

bin_labels = ['1 to lessthan_2', '2 to 3']
train['FCVC_Group'] = pd.cut(train['FCVC'], bins=bin_edges, labels=bin_labels, right=False)
train = pd.get_dummies(train, columns=['FCVC_Group'])
conditions = [
    (train['NCP'] < 2),
    (train['NCP'] >= 2) & (train['NCP'] < 3),
    (train['NCP'] >= 3) & (train['NCP'] <= 4),
]

train['NCP_Group'] = np.select(conditions, ['under_2', 'under_3', '3_to_4'], default='NaN')
train = pd.get_dummies(train, columns=['NCP_Group'])
bin_edges = [1, 1.5, 2, 2.5, 3.1]

bin_labels = ['1-1.5', 'above_1.5-2', 'above_2-2.5', 'above_2.5-3']

train['CH2O_Group'] = pd.cut(train['CH2O'], bins=bin_edges, labels=bin_labels, right=False)
train = pd.get_dummies(train, columns=['CH2O_Group'])
labels = ['0', 'above_0-below_1', '1-below_2', '2-3']

conditions = [
    (train['FAF'] == 0),
    (train['FAF'] > 0) & (train['FAF'] < 1),
    (train['FAF'] >= 1) & (train['FAF'] < 2),
    (train['FAF'] >= 2) & (train['FAF'] <= 3),
]

train['FAF_Group'] = np.select(conditions, labels, default='NaN')
train = pd.get_dummies(train, columns=['FAF_Group'])
bins = [0, 1, 2.1]  
labels = ['0-1', 'above_1-2']

train['TUE_Group'] = pd.cut(train['TUE'], bins=bins, labels=labels, right=False)

train = pd.get_dummies(train, columns=['TUE_Group'])

# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
train['BMI'] = train['Weight'] / (train['Height'] ** 2)

# X[X.columns] = scaler.fit_transform(X[X.columns])
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# Assuming 'train' is your DataFrame and it has a column 'BMI' with the BMI values

# Define a function to map BMI values to categories
def categorize_bmi(bmi):
    if bmi < 18.5:
        return 'Insufficient_Weight'
    elif bmi < 25:
        return 'Normal_Weight'
    elif bmi < 27.2:
        return 'Overweight_Level_I'
    elif bmi < 30:
        return 'Overweight_Level_I'
    elif bmi < 35:
        return 'Obesity_Type_I'
    elif bmi < 40:
        return 'Obesity_Type_II'
    else:
        return 'Obesity_Type_III'

# Apply the function to create a new column with the categories
train['BMI_Category'] = train['BMI'].apply(categorize_bmi)

train = pd.get_dummies(train, columns=['BMI_Category'])
X = train.drop(['NObeyesdad'], axis=1)
y = train['NObeyesdad']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 55 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Gender                            20758 non-null  int64
#  1   Age                               20758 non-null  float64
#  2   Height                            20758 non-null  float64
#  3   Weight                            20758 non-null  float64
#  4   family_history_with_overweight    20758 non-null  int64
#  5   FAVC                              20758 non-null  int64
#  6   FCVC                              20758 non-null  float64
#  7   NCP                               20758 non-null  float64
#  8   CAEC                              20758 non-null  int64
#  9   SMOKE                             20758 non-null  int64
#  10  CH2O                              20758 non-null  float64
#  11  SCC                               20758 non-null  int64
#  12  FAF                               20758 non-null  float64
#  13  TUE                               20758 non-null  float64
#  14  CALC                              20758 non-null  int64
#  15  MTRANS_Automobile                 20758 non-null  bool
#  16  MTRANS_Bike                       20758 non-null  bool
#  17  MTRANS_Motorbike                  20758 non-null  bool
#  18  MTRANS_Public_Transportation      20758 non-null  bool
#  19  MTRANS_Walking                    20758 non-null  bool
#  20  Age_14.0-20                       20758 non-null  bool
#  21  Age_21-30                         20758 non-null  bool
#  22  Age_31-40                         20758 non-null  bool
#  23  Age_41-61.0                       20758 non-null  bool
#  24  Weight_Part 1                     20758 non-null  bool
#  25  Weight_Part 2                     20758 non-null  bool
#  26  Weight_Part 3                     20758 non-null  bool
#  27  Weight_Part 4                     20758 non-null  bool
#  28  Height_Std_Dev_Part 1             20758 non-null  bool
#  29  Height_Std_Dev_Part 2             20758 non-null  bool
#  30  Height_Std_Dev_Part 3             20758 non-null  bool
#  31  Height_Std_Dev_Part 4             20758 non-null  bool
#  32  Height_Std_Dev_Part 5             20758 non-null  bool
#  33  FCVC_Group_1 to lessthan_2        20758 non-null  bool
#  34  FCVC_Group_2 to 3                 20758 non-null  bool
#  35  NCP_Group_3_to_4                  20758 non-null  bool
#  36  NCP_Group_under_2                 20758 non-null  bool
#  37  NCP_Group_under_3                 20758 non-null  bool
#  38  CH2O_Group_1-1.5                  20758 non-null  bool
#  39  CH2O_Group_above_1.5-2            20758 non-null  bool
#  40  CH2O_Group_above_2-2.5            20758 non-null  bool
#  41  CH2O_Group_above_2.5-3            20758 non-null  bool
#  42  FAF_Group_0                       20758 non-null  bool
#  43  FAF_Group_1-below_2               20758 non-null  bool
#  44  FAF_Group_2-3                     20758 non-null  bool
#  45  FAF_Group_above_0-below_1         20758 non-null  bool
#  46  TUE_Group_0-1                     20758 non-null  bool
#  47  TUE_Group_above_1-2               20758 non-null  bool
#  48  BMI                               20758 non-null  float64
#  49  BMI_Category_Insufficient_Weight  20758 non-null  bool
#  50  BMI_Category_Normal_Weight        20758 non-null  bool
#  51  BMI_Category_Obesity_Type_I       20758 non-null  bool
#  52  BMI_Category_Obesity_Type_II      20758 non-null  bool
#  53  BMI_Category_Obesity_Type_III     20758 non-null  bool
#  54  BMI_Category_Overweight_Level_I   20758 non-null  bool
# dtypes: bool(39), float64(9), int64(7)
# memory usage: 3.3 MB

# %%
def objective_xgboost(trial):
    param = {
    'tree_method': 'hist',  # Updated to use 'hist' as the tree method
    'device': 'cuda',
    "objective": "multiclass",         
    'n_estimators': trial.suggest_int('n_estimators', 200, 1000),
    'max_depth': trial.suggest_int('max_depth', 2, 10),
    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.5, log=True),
    'subsample': trial.suggest_float('subsample', 0.5, 1.0),
    'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
    'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
    'gamma': trial.suggest_float('gamma', 0, 5),
#     'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),
#     'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 1.0, log=True),
    }
    
    clf = XGBClassifier(**param, random_state=42, use_label_encoder=False, eval_metric='logloss')
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = cross_val_score(clf, X, y, cv=cv, scoring='accuracy')
    
    return np.mean(scores)

def objective_lightgbm(trial):
    param = {
    'device': 'gpu',  # Use GPU acceleration
    'gpu_platform_id': 0,
    'gpu_device_id': 0,
    "objective": "multiclass",         
    'num_leaves': trial.suggest_int('num_leaves', 100, 400),
    'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 200, 400),
    'max_depth': trial.suggest_int('max_depth', 2, 10),
    'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 1.0),
    'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 1.0),
    'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
    'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0, log=True),
    'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0, log=True),
    'learning_rate': trial.suggest_float('learning_rate', 1e-4, 0.1, log=True),
    'n_estimators': trial.suggest_int('n_estimators', 500, 1000)
    }
    
    clf = LGBMClassifier(**param, random_state=42, verbose=-1)
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = cross_val_score(clf, X, y, cv=cv, scoring='accuracy')
    
    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective_xgboost, n_trials=15)  

study_lgb = optuna.create_study(direction='maximize')
study_lgb.optimize(objective_lightgbm, n_trials=15)
# After optimization
print("Best trial for XGBoost:")
best_trial_xgb = study_xgb.best_trial
print(f"  Value (Accuracy): {best_trial_xgb.value}")
print(f"  Params: ")
for key, value in best_trial_xgb.params.items():
    print(f"    {key}: {value}")

print("\nBest trial for LightGBM:")
best_trial_lgb = study_lgb.best_trial
print(f"  Value (Accuracy): {best_trial_lgb.value}")
print(f"  Params: ")
for key, value in best_trial_lgb.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2024-02-16 20:54:10,019] A new study created in memory with name: no-name-df8921b9-eee1-48d1-aa29-0fc71eb19675
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:54:15] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-02-16 20:54:25,141] Trial 0 finished with value: 0.8864533407630993 and parameters: {'n_estimators': 798, 'max_depth': 5, 'learning_rate': 0.024488866014490154, 'subsample': 0.7104526464856715, 'colsample_bytree': 0.940859629435955, 'min_child_weight': 126, 'gamma': 2.6351934785778464}. Best is trial 0 with value: 0.8864533407630993.
# [I 2024-02-16 20:54:32,642] Trial 1 finished with value: 0.8821176698939365 and parameters: {'n_estimators': 509, 'max_depth': 4, 'learning_rate': 0.13282840533524243, 'subsample': 0.8361162519467047, 'colsample_bytree': 0.6280264320113457, 'min_child_weight': 185, 'gamma': 2.8807960942033892}. Best is trial 0 with value: 0.8864533407630993.
# [I 2024-02-16 20:54:42,215] Trial 2 finished with value: 0.8998456680537604 and parameters: {'n_estimators': 650, 'max_depth': 8, 'learning_rate': 0.11132337910192708, 'subsample': 0.7647822086004024, 'colsample_bytree': 0.7899491337020196, 'min_child_weight': 19, 'gamma': 3.7087522606846957}. Best is trial 2 with value: 0.8998456680537604.
# [I 2024-02-16 20:54:51,715] Trial 3 finished with value: 0.8633297047781917 and parameters: {'n_estimators': 593, 'max_depth': 4, 'learning_rate': 0.046310657339777, 'subsample': 0.5892320375633884, 'colsample_bytree': 0.8680935178554315, 'min_child_weight': 259, 'gamma': 2.14057484994937}. Best is trial 2 with value: 0.8998456680537604.
# [I 2024-02-16 20:54:58,388] Trial 4 finished with value: 0.8662683053366494 and parameters: {'n_estimators': 381, 'max_depth': 8, 'learning_rate': 0.05960181570693022, 'subsample': 0.769477598830336, 'colsample_bytree': 0.7900978573149826, 'min_child_weight': 298, 'gamma': 2.16105291945927}. Best is trial 2 with value: 0.8998456680537604.
# [I 2024-02-16 20:55:05,222] Trial 5 finished with value: 0.8829366289413892 and parameters: {'n_estimators': 330, 'max_depth': 9, 'learning_rate': 0.034258701420546725, 'subsample': 0.6244570172236019, 'colsample_bytree': 0.9571218050678315, 'min_child_weight': 100, 'gamma': 4.764338482127462}. Best is trial 2 with value: 0.8998456680537604.
# [I 2024-02-16 20:55:09,942] Trial 6 finished with value: 0.8832257089397518 and parameters: {'n_estimators': 291, 'max_depth': 5, 'learning_rate': 0.213347634625367, 'subsample': 0.9929672516415423, 'colsample_bytree': 0.6153781343353135, 'min_child_weight': 170, 'gamma': 3.745483790740028}. Best is trial 2 with value: 0.8998456680537604.
# [I 2024-02-16 20:55:19,928] Trial 7 finished with value: 0.892282407132798 and parameters: {'n_estimators': 532, 'max_depth': 5, 'learning_rate': 0.033010136163645995, 'subsample': 0.7040992411063033, 'colsample_bytree': 0.8868686439901502, 'min_child_weight': 52, 'gamma': 3.922536838477498}. Best is trial 2 with value: 0.8998456680537604.
# [I 2024-02-16 20:55:32,692] Trial 8 finished with value: 0.8712783987350462 and parameters: {'n_estimators': 707, 'max_depth': 9, 'learning_rate': 0.022697709970826575, 'subsample': 0.9657762878599176, 'colsample_bytree': 0.8912923474278898, 'min_child_weight': 293, 'gamma': 3.1624978495507734}. Best is trial 2 with value: 0.8998456680537604.
# [I 2024-02-16 20:55:42,510] Trial 9 finished with value: 0.8992195334340862 and parameters: {'n_estimators': 517, 'max_depth': 7, 'learning_rate': 0.053937019416921965, 'subsample': 0.6980118090639413, 'colsample_bytree': 0.9883951520178942, 'min_child_weight': 37, 'gamma': 2.8939654384529274}. Best is trial 2 with value: 0.8998456680537604.
# [I 2024-02-16 20:55:56,918] Trial 10 finished with value: 0.9023026565869136 and parameters: {'n_estimators': 947, 'max_depth': 2, 'learning_rate': 0.4582370203850386, 'subsample': 0.8588524812643338, 'colsample_bytree': 0.7153960299369079, 'min_child_weight': 20, 'gamma': 0.3553545874848334}. Best is trial 10 with value: 0.9023026565869136.
# [I 2024-02-16 20:56:12,347] Trial 11 finished with value: 0.9017726731089533 and parameters: {'n_estimators': 998, 'max_depth': 2, 'learning_rate': 0.4151856544814229, 'subsample': 0.8683560857414268, 'colsample_bytree': 0.72211396864142, 'min_child_weight': 14, 'gamma': 0.29196757498260467}. Best is trial 10 with value: 0.9023026565869136.
# [I 2024-02-16 20:56:27,878] Trial 12 finished with value: 0.9007128523534508 and parameters: {'n_estimators': 955, 'max_depth': 2, 'learning_rate': 0.41835963418108985, 'subsample': 0.8847264841871301, 'colsample_bytree': 0.6886628976053816, 'min_child_weight': 4, 'gamma': 0.10116489793366382}. Best is trial 10 with value: 0.9023026565869136.
# [I 2024-02-16 20:56:43,600] Trial 13 finished with value: 0.9020618644981107 and parameters: {'n_estimators': 992, 'max_depth': 2, 'learning_rate': 0.4874276560069523, 'subsample': 0.8688391307796692, 'colsample_bytree': 0.5061128668666006, 'min_child_weight': 69, 'gamma': 0.09532871845510948}. Best is trial 10 with value: 0.9023026565869136.
# [I 2024-02-16 20:56:55,102] Trial 14 finished with value: 0.9000384367861415 and parameters: {'n_estimators': 844, 'max_depth': 3, 'learning_rate': 0.2388582732004962, 'subsample': 0.923885188384652, 'colsample_bytree': 0.5013246687269528, 'min_child_weight': 77, 'gamma': 0.9406657993732186}. Best is trial 10 with value: 0.9023026565869136.
# [I 2024-02-16 20:56:55,104] A new study created in memory with name: no-name-d814f85b-83c8-45d2-9859-c57376d0fac9
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# [I 2024-02-16 20:57:42,195] Trial 0 finished with value: 0.9040852782862303 and parameters: {'num_leaves': 359, 'min_data_in_leaf': 342, 'max_depth': 9, 'feature_fraction': 0.8309784286920276, 'bagging_fraction': 0.6010454690974987, 'bagging_freq': 5, 'lambda_l1': 9.867109666769589e-07, 'lambda_l2': 6.659573820512639e-05, 'learning_rate': 0.05526569469580798, 'n_estimators': 549}. Best is trial 0 with value: 0.9040852782862303.
# [I 2024-02-16 20:57:59,131] Trial 1 finished with value: 0.8578860296728369 and parameters: {'num_leaves': 324, 'min_data_in_leaf': 230, 'max_depth': 2, 'feature_fraction': 0.9578469170374724, 'bagging_fraction': 0.6495896293712038, 'bagging_freq': 1, 'lambda_l1': 3.9447402227603265e-06, 'lambda_l2': 1.3024240694104198e-07, 'learning_rate': 0.002021948564789352, 'n_estimators': 845}. Best is trial 0 with value: 0.9040852782862303.
# [I 2024-02-16 20:58:57,268] Trial 2 finished with value: 0.9063011544820454 and parameters: {'num_leaves': 101, 'min_data_in_leaf': 371, 'max_depth': 8, 'feature_fraction': 0.9263135414536714, 'bagging_fraction': 0.8850001266461731, 'bagging_freq': 4, 'lambda_l1': 0.22720383500861552, 'lambda_l2': 0.3303409450169313, 'learning_rate': 0.024022864726162482, 'n_estimators': 781}. Best is trial 2 with value: 0.9063011544820454.
# [I 2024-02-16 20:59:28,732] Trial 3 finished with value: 0.5348783166957257 and parameters: {'num_leaves': 261, 'min_data_in_leaf': 282, 'max_depth': 4, 'feature_fraction': 0.51384094661644, 'bagging_fraction': 0.8490137300339314, 'bagging_freq': 5, 'lambda_l1': 8.565864312380979e-08, 'lambda_l2': 0.17295359739461963, 'learning_rate': 0.00012304627164680973, 'n_estimators': 606}. Best is trial 2 with value: 0.9063011544820454.
# [I 2024-02-16 21:00:13,077] Trial 4 finished with value: 0.9062047457491184 and parameters: {'num_leaves': 352, 'min_data_in_leaf': 363, 'max_depth': 5, 'feature_fraction': 0.8033675261553838, 'bagging_fraction': 0.7839334919523517, 'bagging_freq': 3, 'lambda_l1': 2.951500638527499e-05, 'lambda_l2': 3.8946950142541366e-07, 'learning_rate': 0.01724480969921728, 'n_estimators': 744}. Best is trial 2 with value: 0.9063011544820454.
# [I 2024-02-16 21:00:46,703] Trial 5 finished with value: 0.8880912170864569 and parameters: {'num_leaves': 318, 'min_data_in_leaf': 298, 'max_depth': 5, 'feature_fraction': 0.8148715761454763, 'bagging_fraction': 0.7290777534796729, 'bagging_freq': 1, 'lambda_l1': 0.0007700911661962579, 'lambda_l2': 0.27633131229863256, 'learning_rate': 0.003924196219542328, 'n_estimators': 781}. Best is trial 2 with value: 0.9063011544820454.
# [I 2024-02-16 21:01:17,388] Trial 6 finished with value: 0.8477210557285361 and parameters: {'num_leaves': 320, 'min_data_in_leaf': 355, 'max_depth': 9, 'feature_fraction': 0.816777643754832, 'bagging_fraction': 0.606703044520148, 'bagging_freq': 3, 'lambda_l1': 0.0347592954477197, 'lambda_l2': 2.9887479287867325, 'learning_rate': 0.0007307528651485314, 'n_estimators': 736}. Best is trial 2 with value: 0.9063011544820454.
# [I 2024-02-16 21:02:03,359] Trial 7 finished with value: 0.8341843590058483 and parameters: {'num_leaves': 263, 'min_data_in_leaf': 385, 'max_depth': 4, 'feature_fraction': 0.826770765873023, 'bagging_fraction': 0.7159025230816067, 'bagging_freq': 2, 'lambda_l1': 0.001301227872252064, 'lambda_l2': 8.12895166153845e-08, 'learning_rate': 0.00017070411609800598, 'n_estimators': 896}. Best is trial 2 with value: 0.9063011544820454.
# [I 2024-02-16 21:02:34,509] Trial 8 finished with value: 0.6488583905533923 and parameters: {'num_leaves': 385, 'min_data_in_leaf': 219, 'max_depth': 7, 'feature_fraction': 0.8586963744869756, 'bagging_fraction': 0.5551717961325163, 'bagging_freq': 1, 'lambda_l1': 0.01933630115642218, 'lambda_l2': 3.917571561412694e-05, 'learning_rate': 0.00012768815446220896, 'n_estimators': 629}. Best is trial 2 with value: 0.9063011544820454.
# [I 2024-02-16 21:03:06,022] Trial 9 finished with value: 0.8994603812182866 and parameters: {'num_leaves': 265, 'min_data_in_leaf': 381, 'max_depth': 3, 'feature_fraction': 0.9659610524514374, 'bagging_fraction': 0.9214599482385981, 'bagging_freq': 3, 'lambda_l1': 0.0034083876530447157, 'lambda_l2': 2.6683316707665323, 'learning_rate': 0.011299506337448207, 'n_estimators': 786}. Best is trial 2 with value: 0.9063011544820454.
# [I 2024-02-16 21:04:02,618] Trial 10 finished with value: 0.9042778729704946 and parameters: {'num_leaves': 101, 'min_data_in_leaf': 324, 'max_depth': 7, 'feature_fraction': 0.661817156173435, 'bagging_fraction': 0.9727235271012633, 'bagging_freq': 7, 'lambda_l1': 1.98585354559136, 'lambda_l2': 0.005672222927074522, 'learning_rate': 0.08438337906477773, 'n_estimators': 977}. Best is trial 2 with value: 0.9063011544820454.
# [I 2024-02-16 21:04:56,915] Trial 11 finished with value: 0.9067828987839189 and parameters: {'num_leaves': 108, 'min_data_in_leaf': 388, 'max_depth': 7, 'feature_fraction': 0.7223492798822277, 'bagging_fraction': 0.8597176177374756, 'bagging_freq': 4, 'lambda_l1': 1.754125833563235e-05, 'lambda_l2': 1.9593332562502554e-06, 'learning_rate': 0.023508216657606627, 'n_estimators': 688}. Best is trial 11 with value: 0.9067828987839189.
# [I 2024-02-16 21:05:30,965] Trial 12 finished with value: 0.9014836627298375 and parameters: {'num_leaves': 104, 'min_data_in_leaf': 396, 'max_depth': 8, 'feature_fraction': 0.6828769279390382, 'bagging_fraction': 0.8643821773566452, 'bagging_freq': 5, 'lambda_l1': 8.933171704570361, 'lambda_l2': 3.1761503734073496e-06, 'learning_rate': 0.02032976560991186, 'n_estimators': 670}. Best is trial 11 with value: 0.9067828987839189.
# [I 2024-02-16 21:06:19,302] Trial 13 finished with value: 0.8953173537668607 and parameters: {'num_leaves': 162, 'min_data_in_leaf': 265, 'max_depth': 10, 'feature_fraction': 0.6981393063911088, 'bagging_fraction': 0.8298231655246934, 'bagging_freq': 4, 'lambda_l1': 0.2126403390048487, 'lambda_l2': 0.005459328834205701, 'learning_rate': 0.004829459436681619, 'n_estimators': 689}. Best is trial 11 with value: 0.9067828987839189.
# [I 2024-02-16 21:06:59,731] Trial 14 finished with value: 0.907264650047717 and parameters: {'num_leaves': 167, 'min_data_in_leaf': 326, 'max_depth': 7, 'feature_fraction': 0.5650109761829814, 'bagging_fraction': 0.9998950329043939, 'bagging_freq': 7, 'lambda_l1': 6.926171330730737e-05, 'lambda_l2': 0.0015839201547353037, 'learning_rate': 0.031089974530760678, 'n_estimators': 505}. Best is trial 14 with value: 0.907264650047717.
# Best trial for XGBoost:
#   Value (Accuracy): 0.9023026565869136
#   Params:
#     n_estimators: 947
#     max_depth: 2
#     learning_rate: 0.4582370203850386
#     subsample: 0.8588524812643338
#     colsample_bytree: 0.7153960299369079
#     min_child_weight: 20
#     gamma: 0.3553545874848334
#
# Best trial for LightGBM:
#   Value (Accuracy): 0.907264650047717
#   Params:
#     num_leaves: 167
#     min_data_in_leaf: 326
#     max_depth: 7
#     feature_fraction: 0.5650109761829814
#     bagging_fraction: 0.9998950329043939
#     bagging_freq: 7
#     lambda_l1: 6.926171330730737e-05
#     lambda_l2: 0.0015839201547353037
#     learning_rate: 0.031089974530760678
#     n_estimators: 505

# %%
train=pd.read_csv('../input/playground-series-s4e2/train.csv')
test=pd.read_csv('../input/playground-series-s4e2/test.csv')

# %%
# Features to yesno encode:
yesno_encode = ['family_history_with_overweight', 'SMOKE', 'SCC', 'FAVC']

# Features to One-Hot encode: 
oh_encode = ['MTRANS']

# NObeyesdad mapping
NObeyesdad_mapping = {
    'Insufficient_Weight': 0,
    'Normal_Weight': 1,
    'Overweight_Level_I': 2,
    'Overweight_Level_II': 3,
    'Obesity_Type_I': 4,
    'Obesity_Type_II': 5,
    'Obesity_Type_III': 6
}
for column in yesno_encode:
    train[column] = train[column].map({'no': 0, 'yes': 1})
    
train['Gender'] = train['Gender'].map({'Male': 0, 'Female': 1})

train = pd.get_dummies(train, columns=oh_encode, prefix=oh_encode[0])

train = train.drop(['id'], axis=1)

train['CAEC'] = train['CAEC'].map({'no': 0, 'Sometimes': 1, 'Frequently': 2, 'Always': 3})
train['CALC'] = train['CALC'].map({'no': 0, 'Sometimes': 1, 'Frequently': 2})
train['NObeyesdad'] = train['NObeyesdad'].map(NObeyesdad_mapping)
import pandas as pd

min_age = train['Age'].min()
max_age = train['Age'].max()

bins = [min_age-1, 20, 30, 40, max_age+1]

labels = [f'{min_age}-20', '21-30', '31-40', f'41-{max_age}']

# Use pd.cut to categorize 'Age' values with the corrected labels
train['Age_Group'] = pd.cut(train['Age'], bins=bins, labels=labels)

# Apply one-hot encoding to the 'Age_Group' column
train = pd.get_dummies(train, columns=['Age_Group'], prefix='Age')

dummy_columns = [f'Age_{label}' for label in labels]

# train[dummy_columns] = train[dummy_columns].astype(int)
min_weight = train['Weight'].min()
max_weight = train['Weight'].max()

weight_bins = np.linspace(min_weight, max_weight, num=5) 
weight_labels = ['Part 1', 'Part 2', 'Part 3', 'Part 4']
train['Weight_Part'] = pd.cut(train['Weight'], bins=weight_bins, labels=weight_labels, include_lowest=True)

train = pd.get_dummies(train, columns=['Weight_Part'], prefix='Weight')
std_dev_height = train['Height'].std()
mean_height = train['Height'].mean()
# Split height into categories based on standard deviations
bins = [train['Height'].min()] + [mean_height - 2 * std_dev_height] + [mean_height - std_dev_height] + \
       [mean_height + std_dev_height] + [mean_height + 2 * std_dev_height] + [train['Height'].max()]
labels = ['Part 1', 'Part 2', 'Part 3', 'Part 4', 'Part 5']
train['Height_Std_Dev'] = pd.cut(train['Height'], bins=bins, labels=labels, include_lowest=True)

# One-hot encode the Height_Std_Dev feature
train = pd.get_dummies(train, columns=['Height_Std_Dev'], prefix='Height_Std_Dev')
bin_edges = [1, 2, 3.1]

bin_labels = ['1 to lessthan_2', '2 to 3']
train['FCVC_Group'] = pd.cut(train['FCVC'], bins=bin_edges, labels=bin_labels, right=False)
train = pd.get_dummies(train, columns=['FCVC_Group'])
conditions = [
    (train['NCP'] < 2),
    (train['NCP'] >= 2) & (train['NCP'] < 3),
    (train['NCP'] >= 3) & (train['NCP'] <= 4),
]

train['NCP_Group'] = np.select(conditions, ['under_2', 'under_3', '3_to_4'], default='NaN')
train = pd.get_dummies(train, columns=['NCP_Group'])
bin_edges = [1, 1.5, 2, 2.5, 3.1]

bin_labels = ['1-1.5', 'above_1.5-2', 'above_2-2.5', 'above_2.5-3']

train['CH2O_Group'] = pd.cut(train['CH2O'], bins=bin_edges, labels=bin_labels, right=False)
train = pd.get_dummies(train, columns=['CH2O_Group'])
labels = ['0', 'above_0-below_1', '1-below_2', '2-3']

conditions = [
    (train['FAF'] == 0),
    (train['FAF'] > 0) & (train['FAF'] < 1),
    (train['FAF'] >= 1) & (train['FAF'] < 2),
    (train['FAF'] >= 2) & (train['FAF'] <= 3),
]

train['FAF_Group'] = np.select(conditions, labels, default='NaN')
train = pd.get_dummies(train, columns=['FAF_Group'])
bins = [0, 1, 2.1]  
labels = ['0-1', 'above_1-2']

train['TUE_Group'] = pd.cut(train['TUE'], bins=bins, labels=labels, right=False)

train = pd.get_dummies(train, columns=['TUE_Group'])

# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
train['BMI'] = train['Weight'] / (train['Height'] ** 2)

X = train.drop(['NObeyesdad'], axis=1)
y = train['NObeyesdad']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 49 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          20758 non-null  int64
#  1   Age                             20758 non-null  float64
#  2   Height                          20758 non-null  float64
#  3   Weight                          20758 non-null  float64
#  4   family_history_with_overweight  20758 non-null  int64
#  5   FAVC                            20758 non-null  int64
#  6   FCVC                            20758 non-null  float64
#  7   NCP                             20758 non-null  float64
#  8   CAEC                            20758 non-null  int64
#  9   SMOKE                           20758 non-null  int64
#  10  CH2O                            20758 non-null  float64
#  11  SCC                             20758 non-null  int64
#  12  FAF                             20758 non-null  float64
#  13  TUE                             20758 non-null  float64
#  14  CALC                            20758 non-null  int64
#  15  MTRANS_Automobile               20758 non-null  bool
#  16  MTRANS_Bike                     20758 non-null  bool
#  17  MTRANS_Motorbike                20758 non-null  bool
#  18  MTRANS_Public_Transportation    20758 non-null  bool
#  19  MTRANS_Walking                  20758 non-null  bool
#  20  Age_14.0-20                     20758 non-null  bool
#  21  Age_21-30                       20758 non-null  bool
#  22  Age_31-40                       20758 non-null  bool
#  23  Age_41-61.0                     20758 non-null  bool
#  24  Weight_Part 1                   20758 non-null  bool
#  25  Weight_Part 2                   20758 non-null  bool
#  26  Weight_Part 3                   20758 non-null  bool
#  27  Weight_Part 4                   20758 non-null  bool
#  28  Height_Std_Dev_Part 1           20758 non-null  bool
#  29  Height_Std_Dev_Part 2           20758 non-null  bool
#  30  Height_Std_Dev_Part 3           20758 non-null  bool
#  31  Height_Std_Dev_Part 4           20758 non-null  bool
#  32  Height_Std_Dev_Part 5           20758 non-null  bool
#  33  FCVC_Group_1 to lessthan_2      20758 non-null  bool
#  34  FCVC_Group_2 to 3               20758 non-null  bool
#  35  NCP_Group_3_to_4                20758 non-null  bool
#  36  NCP_Group_under_2               20758 non-null  bool
#  37  NCP_Group_under_3               20758 non-null  bool
#  38  CH2O_Group_1-1.5                20758 non-null  bool
#  39  CH2O_Group_above_1.5-2          20758 non-null  bool
#  40  CH2O_Group_above_2-2.5          20758 non-null  bool
#  41  CH2O_Group_above_2.5-3          20758 non-null  bool
#  42  FAF_Group_0                     20758 non-null  bool
#  43  FAF_Group_1-below_2             20758 non-null  bool
#  44  FAF_Group_2-3                   20758 non-null  bool
#  45  FAF_Group_above_0-below_1       20758 non-null  bool
#  46  TUE_Group_0-1                   20758 non-null  bool
#  47  TUE_Group_above_1-2             20758 non-null  bool
#  48  BMI                             20758 non-null  float64
# dtypes: bool(33), float64(9), int64(7)
# memory usage: 3.2 MB

# %%
def objective_xgboost(trial):
    param = {
    'tree_method': 'hist',  # Updated to use 'hist' as the tree method
    'device': 'cuda',
    "objective": "multiclass",         
    'n_estimators': trial.suggest_int('n_estimators', 200, 1000),
    'max_depth': trial.suggest_int('max_depth', 2, 10),
    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.5, log=True),
    'subsample': trial.suggest_float('subsample', 0.5, 1.0),
    'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
    'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
    'gamma': trial.suggest_float('gamma', 0, 5),
#     'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),
#     'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 1.0, log=True),
    }
    
    clf = XGBClassifier(**param, random_state=42, use_label_encoder=False, eval_metric='logloss')
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = cross_val_score(clf, X, y, cv=cv, scoring='accuracy')
    
    return np.mean(scores)

def objective_lightgbm(trial):
    param = {
    'device': 'gpu',  # Use GPU acceleration
    'gpu_platform_id': 0,
    'gpu_device_id': 0,
    "objective": "multiclass",         
    'num_leaves': trial.suggest_int('num_leaves', 100, 400),
    'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 200, 400),
    'max_depth': trial.suggest_int('max_depth', 2, 10),
    'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 1.0),
    'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 1.0),
    'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
    'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0, log=True),
    'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0, log=True),
    'learning_rate': trial.suggest_float('learning_rate', 1e-4, 0.1, log=True),
    'n_estimators': trial.suggest_int('n_estimators', 500, 1000)
    }
    
    clf = LGBMClassifier(**param, random_state=42, verbose=-1)
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = cross_val_score(clf, X, y, cv=cv, scoring='accuracy')
    
    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective_xgboost, n_trials=15)  

study_lgb = optuna.create_study(direction='maximize')
study_lgb.optimize(objective_lightgbm, n_trials=15)
# After optimization
print("Best trial for XGBoost:")
best_trial_xgb = study_xgb.best_trial
print(f"  Value (Accuracy): {best_trial_xgb.value}")
print(f"  Params: ")
for key, value in best_trial_xgb.params.items():
    print(f"    {key}: {value}")

print("\nBest trial for LightGBM:")
best_trial_lgb = study_lgb.best_trial
print(f"  Value (Accuracy): {best_trial_lgb.value}")
print(f"  Params: ")
for key, value in best_trial_lgb.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2024-02-16 21:07:00,141] A new study created in memory with name: no-name-4cd9a15f-98a4-4da4-af67-559833f8a6d6
# [I 2024-02-16 21:07:04,993] Trial 0 finished with value: 0.8884284387939606 and parameters: {'n_estimators': 320, 'max_depth': 8, 'learning_rate': 0.2621337681731364, 'subsample': 0.5694559920759198, 'colsample_bytree': 0.5981622200443464, 'min_child_weight': 108, 'gamma': 3.9438807686464212}. Best is trial 0 with value: 0.8884284387939606.
# [I 2024-02-16 21:07:12,369] Trial 1 finished with value: 0.9033623659516213 and parameters: {'n_estimators': 480, 'max_depth': 8, 'learning_rate': 0.16505119144678818, 'subsample': 0.762827768221431, 'colsample_bytree': 0.6195949690645544, 'min_child_weight': 12, 'gamma': 3.1546877091920758}. Best is trial 1 with value: 0.9033623659516213.
# [I 2024-02-16 21:07:23,281] Trial 2 finished with value: 0.8881393936052215 and parameters: {'n_estimators': 824, 'max_depth': 9, 'learning_rate': 0.3754821180918954, 'subsample': 0.697085093076591, 'colsample_bytree': 0.5908179322329172, 'min_child_weight': 151, 'gamma': 2.7264824138176285}. Best is trial 1 with value: 0.9033623659516213.
# [I 2024-02-16 21:07:28,568] Trial 3 finished with value: 0.8649195925547506 and parameters: {'n_estimators': 323, 'max_depth': 2, 'learning_rate': 0.05775329187556751, 'subsample': 0.5752246221385815, 'colsample_bytree': 0.5464833112476235, 'min_child_weight': 264, 'gamma': 4.151897933018106}. Best is trial 1 with value: 0.9033623659516213.
# [I 2024-02-16 21:07:39,143] Trial 4 finished with value: 0.8833219018530136 and parameters: {'n_estimators': 523, 'max_depth': 3, 'learning_rate': 0.01599205938414959, 'subsample': 0.7175759490272746, 'colsample_bytree': 0.6752062833627104, 'min_child_weight': 114, 'gamma': 2.8612048011131606}. Best is trial 1 with value: 0.9033623659516213.
# [I 2024-02-16 21:07:49,393] Trial 5 finished with value: 0.8977261309716257 and parameters: {'n_estimators': 493, 'max_depth': 10, 'learning_rate': 0.0997803962103777, 'subsample': 0.607491813249206, 'colsample_bytree': 0.8806565874812045, 'min_child_weight': 99, 'gamma': 0.6086094234073225}. Best is trial 1 with value: 0.9033623659516213.
# [I 2024-02-16 21:08:03,777] Trial 6 finished with value: 0.8851044191234602 and parameters: {'n_estimators': 811, 'max_depth': 10, 'learning_rate': 0.021788228602996815, 'subsample': 0.6394081435715327, 'colsample_bytree': 0.8510716627290296, 'min_child_weight': 122, 'gamma': 4.108088391480986}. Best is trial 1 with value: 0.9033623659516213.
# [I 2024-02-16 21:08:13,884] Trial 7 finished with value: 0.8769630469392454 and parameters: {'n_estimators': 588, 'max_depth': 2, 'learning_rate': 0.012591991591727695, 'subsample': 0.8031208854210089, 'colsample_bytree': 0.9273753019077996, 'min_child_weight': 110, 'gamma': 2.1268935596662923}. Best is trial 1 with value: 0.9033623659516213.
# [I 2024-02-16 21:08:26,502] Trial 8 finished with value: 0.9000383880526689 and parameters: {'n_estimators': 867, 'max_depth': 2, 'learning_rate': 0.06019094186885812, 'subsample': 0.6307588162677765, 'colsample_bytree': 0.9379187769488797, 'min_child_weight': 20, 'gamma': 2.7815897327664327}. Best is trial 1 with value: 0.9033623659516213.
# [I 2024-02-16 21:08:33,209] Trial 9 finished with value: 0.8787935806041892 and parameters: {'n_estimators': 245, 'max_depth': 8, 'learning_rate': 0.015587511034925257, 'subsample': 0.8288010003119752, 'colsample_bytree': 0.6446082199542049, 'min_child_weight': 147, 'gamma': 3.797724912130815}. Best is trial 1 with value: 0.9033623659516213.
# [I 2024-02-16 21:08:43,381] Trial 10 finished with value: 0.9030251442441174 and parameters: {'n_estimators': 701, 'max_depth': 5, 'learning_rate': 0.15688767291278902, 'subsample': 0.9773921474578262, 'colsample_bytree': 0.7535326477950075, 'min_child_weight': 3, 'gamma': 1.2390260123772552}. Best is trial 1 with value: 0.9033623659516213.
# [I 2024-02-16 21:08:53,615] Trial 11 finished with value: 0.904470398035512 and parameters: {'n_estimators': 701, 'max_depth': 5, 'learning_rate': 0.1494436627030372, 'subsample': 0.9652472672579715, 'colsample_bytree': 0.7497711520812321, 'min_child_weight': 19, 'gamma': 1.188606328832516}. Best is trial 11 with value: 0.904470398035512.
# [I 2024-02-16 21:09:03,395] Trial 12 finished with value: 0.9011464062127102 and parameters: {'n_estimators': 675, 'max_depth': 6, 'learning_rate': 0.160726182644557, 'subsample': 0.9488078305842255, 'colsample_bytree': 0.7585695525130993, 'min_child_weight': 50, 'gamma': 1.606790918656116}. Best is trial 11 with value: 0.904470398035512.
# [I 2024-02-16 21:09:15,529] Trial 13 finished with value: 0.8918969949826802 and parameters: {'n_estimators': 962, 'max_depth': 5, 'learning_rate': 0.4875077682845224, 'subsample': 0.8792843340222682, 'colsample_bytree': 0.70164264281679, 'min_child_weight': 56, 'gamma': 4.960249259322878}. Best is trial 11 with value: 0.904470398035512.
# [I 2024-02-16 21:09:25,526] Trial 14 finished with value: 0.8853453156411334 and parameters: {'n_estimators': 472, 'max_depth': 7, 'learning_rate': 0.03800235716581627, 'subsample': 0.9126348779811473, 'colsample_bytree': 0.8288440854980057, 'min_child_weight': 213, 'gamma': 0.11742855206047453}. Best is trial 11 with value: 0.904470398035512.
# [I 2024-02-16 21:09:25,528] A new study created in memory with name: no-name-bbd34351-e7a7-423f-bbef-1a1a805add73
# [I 2024-02-16 21:10:01,955] Trial 0 finished with value: 0.9053858075874398 and parameters: {'num_leaves': 175, 'min_data_in_leaf': 380, 'max_depth': 10, 'feature_fraction': 0.64781550545086, 'bagging_fraction': 0.5199064364316948, 'bagging_freq': 3, 'lambda_l1': 2.5163144077137267e-08, 'lambda_l2': 8.390389193077792e-05, 'learning_rate': 0.020042602446446314, 'n_estimators': 517}. Best is trial 0 with value: 0.9053858075874398.
# [I 2024-02-16 21:10:24,721] Trial 1 finished with value: 0.7266592772798145 and parameters: {'num_leaves': 170, 'min_data_in_leaf': 347, 'max_depth': 3, 'feature_fraction': 0.8216741069295905, 'bagging_fraction': 0.8367762283952622, 'bagging_freq': 2, 'lambda_l1': 0.0025800606476204294, 'lambda_l2': 6.252145504435741, 'learning_rate': 0.00019323061326251316, 'n_estimators': 553}. Best is trial 0 with value: 0.9053858075874398.
# [I 2024-02-16 21:11:12,074] Trial 2 finished with value: 0.9034106329754068 and parameters: {'num_leaves': 262, 'min_data_in_leaf': 350, 'max_depth': 6, 'feature_fraction': 0.9764516792550642, 'bagging_fraction': 0.8254166914274039, 'bagging_freq': 7, 'lambda_l1': 9.455359212058551e-06, 'lambda_l2': 4.141966462107482, 'learning_rate': 0.06778707801720714, 'n_estimators': 732}. Best is trial 0 with value: 0.9053858075874398.
# [I 2024-02-16 21:12:18,744] Trial 3 finished with value: 0.9041814572756429 and parameters: {'num_leaves': 391, 'min_data_in_leaf': 351, 'max_depth': 10, 'feature_fraction': 0.767787986071712, 'bagging_fraction': 0.5447264487929844, 'bagging_freq': 7, 'lambda_l1': 0.003114063843097478, 'lambda_l2': 1.536931487997263e-07, 'learning_rate': 0.03531759676490681, 'n_estimators': 931}. Best is trial 0 with value: 0.9053858075874398.
# [I 2024-02-16 21:13:01,093] Trial 4 finished with value: 0.6580597157696784 and parameters: {'num_leaves': 281, 'min_data_in_leaf': 219, 'max_depth': 9, 'feature_fraction': 0.679573276076412, 'bagging_fraction': 0.8286152091916832, 'bagging_freq': 6, 'lambda_l1': 2.84972982551414, 'lambda_l2': 0.029697762866015887, 'learning_rate': 0.0001047367691979853, 'n_estimators': 814}. Best is trial 0 with value: 0.9053858075874398.
# [I 2024-02-16 21:14:05,920] Trial 5 finished with value: 0.9038924190488284 and parameters: {'num_leaves': 200, 'min_data_in_leaf': 329, 'max_depth': 8, 'feature_fraction': 0.8233162257985359, 'bagging_fraction': 0.9807976026649525, 'bagging_freq': 7, 'lambda_l1': 0.18313069412990743, 'lambda_l2': 1.3226424167036315e-05, 'learning_rate': 0.04208151882540355, 'n_estimators': 794}. Best is trial 0 with value: 0.9053858075874398.
# [I 2024-02-16 21:14:34,398] Trial 6 finished with value: 0.9022544313346762 and parameters: {'num_leaves': 397, 'min_data_in_leaf': 361, 'max_depth': 3, 'feature_fraction': 0.7607006940635461, 'bagging_fraction': 0.7698438141834749, 'bagging_freq': 1, 'lambda_l1': 0.000399922084297558, 'lambda_l2': 1.3392385423879455e-07, 'learning_rate': 0.009855948132566435, 'n_estimators': 926}. Best is trial 0 with value: 0.9053858075874398.
# [I 2024-02-16 21:15:03,423] Trial 7 finished with value: 0.8416514339754734 and parameters: {'num_leaves': 300, 'min_data_in_leaf': 279, 'max_depth': 9, 'feature_fraction': 0.9796255368422835, 'bagging_fraction': 0.6358861247772916, 'bagging_freq': 7, 'lambda_l1': 6.312875224534444e-06, 'lambda_l2': 1.9196665074138388, 'learning_rate': 0.00025107747627605776, 'n_estimators': 685}. Best is trial 0 with value: 0.9053858075874398.
# [I 2024-02-16 21:15:28,549] Trial 8 finished with value: 0.8298004211128999 and parameters: {'num_leaves': 335, 'min_data_in_leaf': 273, 'max_depth': 8, 'feature_fraction': 0.8702287590458498, 'bagging_fraction': 0.5948841984606021, 'bagging_freq': 2, 'lambda_l1': 1.076660388807619e-07, 'lambda_l2': 4.280642195425062, 'learning_rate': 0.00024024284879366117, 'n_estimators': 539}. Best is trial 0 with value: 0.9053858075874398.
# [I 2024-02-16 21:16:08,371] Trial 9 finished with value: 0.9037960381636002 and parameters: {'num_leaves': 354, 'min_data_in_leaf': 344, 'max_depth': 5, 'feature_fraction': 0.7382556267734828, 'bagging_fraction': 0.8252539462974715, 'bagging_freq': 6, 'lambda_l1': 0.447594993399061, 'lambda_l2': 0.07165128663906763, 'learning_rate': 0.009432800699193767, 'n_estimators': 749}. Best is trial 0 with value: 0.9053858075874398.
# [I 2024-02-16 21:16:41,191] Trial 10 finished with value: 0.8684844460856022 and parameters: {'num_leaves': 106, 'min_data_in_leaf': 396, 'max_depth': 5, 'feature_fraction': 0.5014446921103503, 'bagging_fraction': 0.5167053442789352, 'bagging_freq': 4, 'lambda_l1': 8.602001248153265e-08, 'lambda_l2': 9.750707492383904e-05, 'learning_rate': 0.0014668696190733841, 'n_estimators': 609}. Best is trial 0 with value: 0.9053858075874398.
# [I 2024-02-16 21:17:46,112] Trial 11 finished with value: 0.9071682761244135 and parameters: {'num_leaves': 186, 'min_data_in_leaf': 382, 'max_depth': 10, 'feature_fraction': 0.6045483452010101, 'bagging_fraction': 0.5229943685343548, 'bagging_freq': 4, 'lambda_l1': 0.011192190982014624, 'lambda_l2': 1.2467559826220523e-08, 'learning_rate': 0.017958218859871474, 'n_estimators': 962}. Best is trial 11 with value: 0.9071682761244135.
# [I 2024-02-16 21:19:07,545] Trial 12 finished with value: 0.9061566736592237 and parameters: {'num_leaves': 194, 'min_data_in_leaf': 397, 'max_depth': 10, 'feature_fraction': 0.5918029916322536, 'bagging_fraction': 0.6604382389854673, 'bagging_freq': 4, 'lambda_l1': 6.748199951337013e-06, 'lambda_l2': 3.2767056498429176e-06, 'learning_rate': 0.011005132591080574, 'n_estimators': 998}. Best is trial 11 with value: 0.9071682761244135.
# [I 2024-02-16 21:20:19,428] Trial 13 finished with value: 0.8844781313414432 and parameters: {'num_leaves': 211, 'min_data_in_leaf': 400, 'max_depth': 7, 'feature_fraction': 0.5532260266264666, 'bagging_fraction': 0.6730697511397673, 'bagging_freq': 4, 'lambda_l1': 7.776428746329375e-06, 'lambda_l2': 1.9262185504781976e-06, 'learning_rate': 0.0026308551892166698, 'n_estimators': 988}. Best is trial 11 with value: 0.9071682761244135.
# [I 2024-02-16 21:21:32,329] Trial 14 finished with value: 0.9056266553716402 and parameters: {'num_leaves': 120, 'min_data_in_leaf': 312, 'max_depth': 10, 'feature_fraction': 0.5819640256727865, 'bagging_fraction': 0.70490673462915, 'bagging_freq': 5, 'lambda_l1': 0.027465943034895912, 'lambda_l2': 1.2075453329148016e-08, 'learning_rate': 0.006868656279321878, 'n_estimators': 992}. Best is trial 11 with value: 0.9071682761244135.
# Best trial for XGBoost:
#   Value (Accuracy): 0.904470398035512
#   Params:
#     n_estimators: 701
#     max_depth: 5
#     learning_rate: 0.1494436627030372
#     subsample: 0.9652472672579715
#     colsample_bytree: 0.7497711520812321
#     min_child_weight: 19
#     gamma: 1.188606328832516
#
# Best trial for LightGBM:
#   Value (Accuracy): 0.9071682761244135
#   Params:
#     num_leaves: 186
#     min_data_in_leaf: 382
#     max_depth: 10
#     feature_fraction: 0.6045483452010101
#     bagging_fraction: 0.5229943685343548
#     bagging_freq: 4
#     lambda_l1: 0.011192190982014624
#     lambda_l2: 1.2467559826220523e-08
#     learning_rate: 0.017958218859871474
#     n_estimators: 962

# %%
train=pd.read_csv('../input/playground-series-s4e2/train.csv')
test=pd.read_csv('../input/playground-series-s4e2/test.csv')

# %%
# Features to yesno encode:
yesno_encode = ['family_history_with_overweight', 'SMOKE', 'SCC', 'FAVC']

# Features to One-Hot encode: 
oh_encode = ['MTRANS']

# NObeyesdad mapping
NObeyesdad_mapping = {
    'Insufficient_Weight': 0,
    'Normal_Weight': 1,
    'Overweight_Level_I': 2,
    'Overweight_Level_II': 3,
    'Obesity_Type_I': 4,
    'Obesity_Type_II': 5,
    'Obesity_Type_III': 6
}
for column in yesno_encode:
    train[column] = train[column].map({'no': 0, 'yes': 1})
    
train['Gender'] = train['Gender'].map({'Male': 0, 'Female': 1})

train = pd.get_dummies(train, columns=oh_encode, prefix=oh_encode[0])

train = train.drop(['id'], axis=1)

train['CAEC'] = train['CAEC'].map({'no': 0, 'Sometimes': 1, 'Frequently': 2, 'Always': 3})
train['CALC'] = train['CALC'].map({'no': 0, 'Sometimes': 1, 'Frequently': 2})
train['NObeyesdad'] = train['NObeyesdad'].map(NObeyesdad_mapping)
import pandas as pd

min_age = train['Age'].min()
max_age = train['Age'].max()

bins = [min_age-1, 20, 30, 40, max_age+1]

labels = [f'{min_age}-20', '21-30', '31-40', f'41-{max_age}']

# Use pd.cut to categorize 'Age' values with the corrected labels
train['Age_Group'] = pd.cut(train['Age'], bins=bins, labels=labels)

# Apply one-hot encoding to the 'Age_Group' column
train = pd.get_dummies(train, columns=['Age_Group'], prefix='Age')

dummy_columns = [f'Age_{label}' for label in labels]

# train[dummy_columns] = train[dummy_columns].astype(int)
min_weight = train['Weight'].min()
max_weight = train['Weight'].max()

weight_bins = np.linspace(min_weight, max_weight, num=5) 
weight_labels = ['Part 1', 'Part 2', 'Part 3', 'Part 4']
train['Weight_Part'] = pd.cut(train['Weight'], bins=weight_bins, labels=weight_labels, include_lowest=True)

train = pd.get_dummies(train, columns=['Weight_Part'], prefix='Weight')
std_dev_height = train['Height'].std()
mean_height = train['Height'].mean()
# Split height into categories based on standard deviations
bins = [train['Height'].min()] + [mean_height - 2 * std_dev_height] + [mean_height - std_dev_height] + \
       [mean_height + std_dev_height] + [mean_height + 2 * std_dev_height] + [train['Height'].max()]
labels = ['Part 1', 'Part 2', 'Part 3', 'Part 4', 'Part 5']
train['Height_Std_Dev'] = pd.cut(train['Height'], bins=bins, labels=labels, include_lowest=True)

# One-hot encode the Height_Std_Dev feature
train = pd.get_dummies(train, columns=['Height_Std_Dev'], prefix='Height_Std_Dev')
bin_edges = [1, 2, 3.1]

bin_labels = ['1 to lessthan_2', '2 to 3']
train['FCVC_Group'] = pd.cut(train['FCVC'], bins=bin_edges, labels=bin_labels, right=False)
train = pd.get_dummies(train, columns=['FCVC_Group'])
conditions = [
    (train['NCP'] < 2),
    (train['NCP'] >= 2) & (train['NCP'] < 3),
    (train['NCP'] >= 3) & (train['NCP'] <= 4),
]

train['NCP_Group'] = np.select(conditions, ['under_2', 'under_3', '3_to_4'], default='NaN')
train = pd.get_dummies(train, columns=['NCP_Group'])
bin_edges = [1, 1.5, 2, 2.5, 3.1]

bin_labels = ['1-1.5', 'above_1.5-2', 'above_2-2.5', 'above_2.5-3']

train['CH2O_Group'] = pd.cut(train['CH2O'], bins=bin_edges, labels=bin_labels, right=False)
train = pd.get_dummies(train, columns=['CH2O_Group'])
labels = ['0', 'above_0-below_1', '1-below_2', '2-3']

conditions = [
    (train['FAF'] == 0),
    (train['FAF'] > 0) & (train['FAF'] < 1),
    (train['FAF'] >= 1) & (train['FAF'] < 2),
    (train['FAF'] >= 2) & (train['FAF'] <= 3),
]

train['FAF_Group'] = np.select(conditions, labels, default='NaN')
train = pd.get_dummies(train, columns=['FAF_Group'])
bins = [0, 1, 2.1]  
labels = ['0-1', 'above_1-2']

train['TUE_Group'] = pd.cut(train['TUE'], bins=bins, labels=labels, right=False)

train = pd.get_dummies(train, columns=['TUE_Group'])

# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()

X = train.drop(['NObeyesdad'], axis=1)
y = train['NObeyesdad']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 48 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          20758 non-null  int64
#  1   Age                             20758 non-null  float64
#  2   Height                          20758 non-null  float64
#  3   Weight                          20758 non-null  float64
#  4   family_history_with_overweight  20758 non-null  int64
#  5   FAVC                            20758 non-null  int64
#  6   FCVC                            20758 non-null  float64
#  7   NCP                             20758 non-null  float64
#  8   CAEC                            20758 non-null  int64
#  9   SMOKE                           20758 non-null  int64
#  10  CH2O                            20758 non-null  float64
#  11  SCC                             20758 non-null  int64
#  12  FAF                             20758 non-null  float64
#  13  TUE                             20758 non-null  float64
#  14  CALC                            20758 non-null  int64
#  15  MTRANS_Automobile               20758 non-null  bool
#  16  MTRANS_Bike                     20758 non-null  bool
#  17  MTRANS_Motorbike                20758 non-null  bool
#  18  MTRANS_Public_Transportation    20758 non-null  bool
#  19  MTRANS_Walking                  20758 non-null  bool
#  20  Age_14.0-20                     20758 non-null  bool
#  21  Age_21-30                       20758 non-null  bool
#  22  Age_31-40                       20758 non-null  bool
#  23  Age_41-61.0                     20758 non-null  bool
#  24  Weight_Part 1                   20758 non-null  bool
#  25  Weight_Part 2                   20758 non-null  bool
#  26  Weight_Part 3                   20758 non-null  bool
#  27  Weight_Part 4                   20758 non-null  bool
#  28  Height_Std_Dev_Part 1           20758 non-null  bool
#  29  Height_Std_Dev_Part 2           20758 non-null  bool
#  30  Height_Std_Dev_Part 3           20758 non-null  bool
#  31  Height_Std_Dev_Part 4           20758 non-null  bool
#  32  Height_Std_Dev_Part 5           20758 non-null  bool
#  33  FCVC_Group_1 to lessthan_2      20758 non-null  bool
#  34  FCVC_Group_2 to 3               20758 non-null  bool
#  35  NCP_Group_3_to_4                20758 non-null  bool
#  36  NCP_Group_under_2               20758 non-null  bool
#  37  NCP_Group_under_3               20758 non-null  bool
#  38  CH2O_Group_1-1.5                20758 non-null  bool
#  39  CH2O_Group_above_1.5-2          20758 non-null  bool
#  40  CH2O_Group_above_2-2.5          20758 non-null  bool
#  41  CH2O_Group_above_2.5-3          20758 non-null  bool
#  42  FAF_Group_0                     20758 non-null  bool
#  43  FAF_Group_1-below_2             20758 non-null  bool
#  44  FAF_Group_2-3                   20758 non-null  bool
#  45  FAF_Group_above_0-below_1       20758 non-null  bool
#  46  TUE_Group_0-1                   20758 non-null  bool
#  47  TUE_Group_above_1-2             20758 non-null  bool
# dtypes: bool(33), float64(8), int64(7)
# memory usage: 3.0 MB

# %%
def objective_xgboost(trial):
    param = {
    'tree_method': 'hist',  # Updated to use 'hist' as the tree method
    'device': 'cuda',
    "objective": "multiclass",         
    'n_estimators': trial.suggest_int('n_estimators', 200, 1000),
    'max_depth': trial.suggest_int('max_depth', 2, 10),
    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.5, log=True),
    'subsample': trial.suggest_float('subsample', 0.5, 1.0),
    'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
    'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
    'gamma': trial.suggest_float('gamma', 0, 5),
#     'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),
#     'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 1.0, log=True),
    }
    
    clf = XGBClassifier(**param, random_state=42, use_label_encoder=False, eval_metric='logloss')
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = cross_val_score(clf, X, y, cv=cv, scoring='accuracy')
    
    return np.mean(scores)

def objective_lightgbm(trial):
    param = {
    'device': 'gpu',  # Use GPU acceleration
    'gpu_platform_id': 0,
    'gpu_device_id': 0,
    "objective": "multiclass",         
    'num_leaves': trial.suggest_int('num_leaves', 100, 400),
    'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 200, 400),
    'max_depth': trial.suggest_int('max_depth', 2, 10),
    'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 1.0),
    'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 1.0),
    'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
    'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0, log=True),
    'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0, log=True),
    'learning_rate': trial.suggest_float('learning_rate', 1e-4, 0.1, log=True),
    'n_estimators': trial.suggest_int('n_estimators', 500, 1000)
    }
    
    clf = LGBMClassifier(**param, random_state=42, verbose=-1)
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = cross_val_score(clf, X, y, cv=cv, scoring='accuracy')
    
    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective_xgboost, n_trials=15)  

study_lgb = optuna.create_study(direction='maximize')
study_lgb.optimize(objective_lightgbm, n_trials=15)
# After optimization
print("Best trial for XGBoost:")
best_trial_xgb = study_xgb.best_trial
print(f"  Value (Accuracy): {best_trial_xgb.value}")
print(f"  Params: ")
for key, value in best_trial_xgb.params.items():
    print(f"    {key}: {value}")

print("\nBest trial for LightGBM:")
best_trial_lgb = study_lgb.best_trial
print(f"  Value (Accuracy): {best_trial_lgb.value}")
print(f"  Params: ")
for key, value in best_trial_lgb.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2024-02-16 21:21:32,803] A new study created in memory with name: no-name-fc9365f5-3189-4b1a-aca4-66235edc3fea
# [I 2024-02-16 21:21:44,003] Trial 0 finished with value: 0.8984004838816128 and parameters: {'n_estimators': 708, 'max_depth': 6, 'learning_rate': 0.0661101219283377, 'subsample': 0.6377496064570045, 'colsample_bytree': 0.6266119715486889, 'min_child_weight': 63, 'gamma': 2.681988256525682}. Best is trial 0 with value: 0.8984004838816128.
# [I 2024-02-16 21:21:59,549] Trial 1 finished with value: 0.8792754571826316 and parameters: {'n_estimators': 993, 'max_depth': 2, 'learning_rate': 0.20531526245061382, 'subsample': 0.894021623549951, 'colsample_bytree': 0.63370872732861, 'min_child_weight': 262, 'gamma': 0.000967711721840403}. Best is trial 0 with value: 0.8984004838816128.
# [I 2024-02-16 21:22:07,476] Trial 2 finished with value: 0.8639079970514857 and parameters: {'n_estimators': 499, 'max_depth': 3, 'learning_rate': 0.46312507788499296, 'subsample': 0.7295884485391909, 'colsample_bytree': 0.703176191253724, 'min_child_weight': 285, 'gamma': 0.5332374095906506}. Best is trial 0 with value: 0.8984004838816128.
# [I 2024-02-16 21:22:17,628] Trial 3 finished with value: 0.863088822184368 and parameters: {'n_estimators': 491, 'max_depth': 9, 'learning_rate': 0.031879652057240686, 'subsample': 0.8506356432106038, 'colsample_bytree': 0.7694517653953169, 'min_child_weight': 283, 'gamma': 1.0246438747138953}. Best is trial 0 with value: 0.8984004838816128.
# [I 2024-02-16 21:22:26,300] Trial 4 finished with value: 0.8615472919366153 and parameters: {'n_estimators': 417, 'max_depth': 3, 'learning_rate': 0.011508587508354323, 'subsample': 0.6857590996377072, 'colsample_bytree': 0.8537958238430334, 'min_child_weight': 134, 'gamma': 0.5345695997335631}. Best is trial 0 with value: 0.8984004838816128.
# [I 2024-02-16 21:22:36,254] Trial 5 finished with value: 0.8680507251401505 and parameters: {'n_estimators': 722, 'max_depth': 5, 'learning_rate': 0.13104392104177803, 'subsample': 0.7766577173360162, 'colsample_bytree': 0.9938207767540544, 'min_child_weight': 241, 'gamma': 4.54590002000529}. Best is trial 0 with value: 0.8984004838816128.
# [I 2024-02-16 21:22:52,368] Trial 6 finished with value: 0.8250313634706697 and parameters: {'n_estimators': 862, 'max_depth': 7, 'learning_rate': 0.010035275542122517, 'subsample': 0.5073798829908016, 'colsample_bytree': 0.7552907729180316, 'min_child_weight': 278, 'gamma': 2.5600923395562205}. Best is trial 0 with value: 0.8984004838816128.
# [I 2024-02-16 21:22:57,366] Trial 7 finished with value: 0.8962808841421559 and parameters: {'n_estimators': 248, 'max_depth': 5, 'learning_rate': 0.06845911175947263, 'subsample': 0.9417248447367931, 'colsample_bytree': 0.8080885252515295, 'min_child_weight': 76, 'gamma': 3.937149129359223}. Best is trial 0 with value: 0.8984004838816128.
# [I 2024-02-16 21:23:06,888] Trial 8 finished with value: 0.8758069775750837 and parameters: {'n_estimators': 584, 'max_depth': 3, 'learning_rate': 0.05053042042025865, 'subsample': 0.617137644903005, 'colsample_bytree': 0.5864097664871476, 'min_child_weight': 157, 'gamma': 3.221606194333306}. Best is trial 0 with value: 0.8984004838816128.
# [I 2024-02-16 21:23:18,921] Trial 9 finished with value: 0.858608684416233 and parameters: {'n_estimators': 880, 'max_depth': 3, 'learning_rate': 0.186644917989633, 'subsample': 0.7091955548024935, 'colsample_bytree': 0.738912230844263, 'min_child_weight': 287, 'gamma': 2.3203484972201105}. Best is trial 0 with value: 0.8984004838816128.
# [I 2024-02-16 21:23:35,902] Trial 10 finished with value: 0.9060601396116527 and parameters: {'n_estimators': 700, 'max_depth': 8, 'learning_rate': 0.025472331561607543, 'subsample': 0.5529413633720852, 'colsample_bytree': 0.5023152680648607, 'min_child_weight': 12, 'gamma': 1.7830382454304468}. Best is trial 10 with value: 0.9060601396116527.
# [I 2024-02-16 21:23:52,523] Trial 11 finished with value: 0.9056265787904686 and parameters: {'n_estimators': 690, 'max_depth': 8, 'learning_rate': 0.024475410807893602, 'subsample': 0.5446970754843332, 'colsample_bytree': 0.5244492888568704, 'min_child_weight': 4, 'gamma': 2.036031777380348}. Best is trial 10 with value: 0.9060601396116527.
# [I 2024-02-16 21:24:11,583] Trial 12 finished with value: 0.9073126942899129 and parameters: {'n_estimators': 714, 'max_depth': 10, 'learning_rate': 0.02375022730516699, 'subsample': 0.5040787235960891, 'colsample_bytree': 0.5018650877369993, 'min_child_weight': 1, 'gamma': 1.6773255256851183}. Best is trial 12 with value: 0.9073126942899129.
# [I 2024-02-16 21:24:32,061] Trial 13 finished with value: 0.9051448136028211 and parameters: {'n_estimators': 810, 'max_depth': 10, 'learning_rate': 0.021823774444629365, 'subsample': 0.569852185724008, 'colsample_bytree': 0.5027889759448271, 'min_child_weight': 22, 'gamma': 1.4989220908794234}. Best is trial 12 with value: 0.9073126942899129.
# [I 2024-02-16 21:24:47,932] Trial 14 finished with value: 0.899075003877792 and parameters: {'n_estimators': 620, 'max_depth': 10, 'learning_rate': 0.018042979078112763, 'subsample': 0.5114226540460363, 'colsample_bytree': 0.5653485484710077, 'min_child_weight': 50, 'gamma': 1.8354385213183153}. Best is trial 12 with value: 0.9073126942899129.
# [I 2024-02-16 21:24:47,933] A new study created in memory with name: no-name-352370fe-ed4e-4bc9-a887-97be1a70a00d
# [I 2024-02-16 21:25:22,037] Trial 0 finished with value: 0.703535376741769 and parameters: {'num_leaves': 297, 'min_data_in_leaf': 229, 'max_depth': 4, 'feature_fraction': 0.5670459789915052, 'bagging_fraction': 0.6443453154218326, 'bagging_freq': 7, 'lambda_l1': 0.011047558098762431, 'lambda_l2': 6.502671408132476e-05, 'learning_rate': 0.00017868958469156103, 'n_estimators': 715}. Best is trial 0 with value: 0.703535376741769.
# [I 2024-02-16 21:26:22,655] Trial 1 finished with value: 0.8689180417164097 and parameters: {'num_leaves': 140, 'min_data_in_leaf': 394, 'max_depth': 8, 'feature_fraction': 0.6856334254442291, 'bagging_fraction': 0.7876646745468561, 'bagging_freq': 5, 'lambda_l1': 4.795443661032065e-05, 'lambda_l2': 0.0008911571337676578, 'learning_rate': 0.0014517921444931992, 'n_estimators': 852}. Best is trial 1 with value: 0.8689180417164097.
# [I 2024-02-16 21:26:56,166] Trial 2 finished with value: 0.851045458304894 and parameters: {'num_leaves': 217, 'min_data_in_leaf': 335, 'max_depth': 6, 'feature_fraction': 0.5849048587467299, 'bagging_fraction': 0.5209456260598939, 'bagging_freq': 1, 'lambda_l1': 0.09867534750759763, 'lambda_l2': 4.351363074543884e-07, 'learning_rate': 0.0010464114483291764, 'n_estimators': 788}. Best is trial 1 with value: 0.8689180417164097.
# [I 2024-02-16 21:27:24,710] Trial 3 finished with value: 0.8355817077935406 and parameters: {'num_leaves': 187, 'min_data_in_leaf': 260, 'max_depth': 4, 'feature_fraction': 0.8741433336965414, 'bagging_fraction': 0.9953563743156167, 'bagging_freq': 7, 'lambda_l1': 0.07677596543646595, 'lambda_l2': 1.7058109830427476e-06, 'learning_rate': 0.0004027532531226168, 'n_estimators': 597}. Best is trial 1 with value: 0.8689180417164097.
# [I 2024-02-16 21:27:57,868] Trial 4 finished with value: 0.6496773217531463 and parameters: {'num_leaves': 201, 'min_data_in_leaf': 398, 'max_depth': 5, 'feature_fraction': 0.7968225665266702, 'bagging_fraction': 0.5023940548692268, 'bagging_freq': 4, 'lambda_l1': 0.0012377804439567157, 'lambda_l2': 6.352729401309462e-08, 'learning_rate': 0.00015740614758370618, 'n_estimators': 758}. Best is trial 1 with value: 0.8689180417164097.
# [I 2024-02-16 21:28:42,889] Trial 5 finished with value: 0.8999902463435275 and parameters: {'num_leaves': 174, 'min_data_in_leaf': 294, 'max_depth': 4, 'feature_fraction': 0.8369949030579135, 'bagging_fraction': 0.9091473455336712, 'bagging_freq': 4, 'lambda_l1': 2.3815380812260172e-05, 'lambda_l2': 2.355571890776991, 'learning_rate': 0.00592095520796429, 'n_estimators': 979}. Best is trial 5 with value: 0.8999902463435275.
# [I 2024-02-16 21:29:03,224] Trial 6 finished with value: 0.8748913870131143 and parameters: {'num_leaves': 299, 'min_data_in_leaf': 362, 'max_depth': 2, 'feature_fraction': 0.915500004219518, 'bagging_fraction': 0.6735808530057799, 'bagging_freq': 4, 'lambda_l1': 0.2073647480678514, 'lambda_l2': 7.209662711221468e-07, 'learning_rate': 0.006921334078032933, 'n_estimators': 751}. Best is trial 5 with value: 0.8999902463435275.
# [I 2024-02-16 21:29:45,343] Trial 7 finished with value: 0.9030253322160836 and parameters: {'num_leaves': 206, 'min_data_in_leaf': 371, 'max_depth': 8, 'feature_fraction': 0.5517970939039274, 'bagging_fraction': 0.9657378598333064, 'bagging_freq': 1, 'lambda_l1': 0.0012085415623722595, 'lambda_l2': 2.8169490821759737, 'learning_rate': 0.0914327151186351, 'n_estimators': 599}. Best is trial 7 with value: 0.9030253322160836.
# [I 2024-02-16 21:30:04,645] Trial 8 finished with value: 0.9030251442441174 and parameters: {'num_leaves': 112, 'min_data_in_leaf': 370, 'max_depth': 3, 'feature_fraction': 0.9885139917266679, 'bagging_fraction': 0.7159663814766017, 'bagging_freq': 4, 'lambda_l1': 1.1176447502953072e-07, 'lambda_l2': 2.011163956262774, 'learning_rate': 0.018468404480967034, 'n_estimators': 520}. Best is trial 7 with value: 0.9030253322160836.
# [I 2024-02-16 21:30:27,232] Trial 9 finished with value: 0.8180462068510352 and parameters: {'num_leaves': 225, 'min_data_in_leaf': 392, 'max_depth': 3, 'feature_fraction': 0.839403923744717, 'bagging_fraction': 0.7958219976025981, 'bagging_freq': 5, 'lambda_l1': 8.701084738853483, 'lambda_l2': 6.356659547375915e-05, 'learning_rate': 0.0005356002657618343, 'n_estimators': 687}. Best is trial 7 with value: 0.9030253322160836.
# [I 2024-02-16 21:31:14,129] Trial 10 finished with value: 0.9037960381636002 and parameters: {'num_leaves': 386, 'min_data_in_leaf': 327, 'max_depth': 9, 'feature_fraction': 0.6761606560520292, 'bagging_fraction': 0.8944025284110484, 'bagging_freq': 1, 'lambda_l1': 3.7149241502689237e-07, 'lambda_l2': 0.0519773531297721, 'learning_rate': 0.049851139145541255, 'n_estimators': 611}. Best is trial 10 with value: 0.9037960381636002.
# [I 2024-02-16 21:32:03,635] Trial 11 finished with value: 0.9008574933005399 and parameters: {'num_leaves': 397, 'min_data_in_leaf': 322, 'max_depth': 10, 'feature_fraction': 0.6781122000782482, 'bagging_fraction': 0.9117051673845752, 'bagging_freq': 1, 'lambda_l1': 3.6400481558064414e-08, 'lambda_l2': 0.03204381097309059, 'learning_rate': 0.08381544008669753, 'n_estimators': 595}. Best is trial 10 with value: 0.9037960381636002.
# [I 2024-02-16 21:32:53,647] Trial 12 finished with value: 0.9016282479815292 and parameters: {'num_leaves': 400, 'min_data_in_leaf': 300, 'max_depth': 8, 'feature_fraction': 0.5014513990494662, 'bagging_fraction': 0.9916693851604206, 'bagging_freq': 2, 'lambda_l1': 1.3181954986755112e-06, 'lambda_l2': 0.03286375486527361, 'learning_rate': 0.08355881673027768, 'n_estimators': 504}. Best is trial 10 with value: 0.9037960381636002.
# [I 2024-02-16 21:33:49,446] Trial 13 finished with value: 0.9072164108716301 and parameters: {'num_leaves': 282, 'min_data_in_leaf': 347, 'max_depth': 9, 'feature_fraction': 0.6866682000664187, 'bagging_fraction': 0.8893604614952969, 'bagging_freq': 2, 'lambda_l1': 2.723930153939794e-06, 'lambda_l2': 0.09842963592807705, 'learning_rate': 0.02583441687310229, 'n_estimators': 613}. Best is trial 13 with value: 0.9072164108716301.
# [I 2024-02-16 21:34:50,813] Trial 14 finished with value: 0.90745727257968 and parameters: {'num_leaves': 336, 'min_data_in_leaf': 334, 'max_depth': 10, 'feature_fraction': 0.7139243917899806, 'bagging_fraction': 0.8435783424786866, 'bagging_freq': 2, 'lambda_l1': 1.502060499957881e-06, 'lambda_l2': 0.07274819359575113, 'learning_rate': 0.025162153450037677, 'n_estimators': 650}. Best is trial 14 with value: 0.90745727257968.
# Best trial for XGBoost:
#   Value (Accuracy): 0.9073126942899129
#   Params:
#     n_estimators: 714
#     max_depth: 10
#     learning_rate: 0.02375022730516699
#     subsample: 0.5040787235960891
#     colsample_bytree: 0.5018650877369993
#     min_child_weight: 1
#     gamma: 1.6773255256851183
#
# Best trial for LightGBM:
#   Value (Accuracy): 0.90745727257968
#   Params:
#     num_leaves: 336
#     min_data_in_leaf: 334
#     max_depth: 10
#     feature_fraction: 0.7139243917899806
#     bagging_fraction: 0.8435783424786866
#     bagging_freq: 2
#     lambda_l1: 1.502060499957881e-06
#     lambda_l2: 0.07274819359575113
#     learning_rate: 0.025162153450037677
#     n_estimators: 650

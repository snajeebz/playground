# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/new-zealand-international-trade-quarter-3-2023/goods_classification.csv
# /kaggle/input/new-zealand-international-trade-quarter-3-2023/output_csv_full.csv
# /kaggle/input/new-zealand-international-trade-quarter-3-2023/services_classification.csv
# /kaggle/input/new-zealand-international-trade-quarter-3-2023/revised.csv
# /kaggle/input/new-zealand-international-trade-quarter-3-2023/country_classification.csv

# %%
df = pd.read_csv("/kaggle/input/new-zealand-international-trade-quarter-3-2023/output_csv_full.csv")
service_df = pd.read_csv("/kaggle/input/new-zealand-international-trade-quarter-3-2023/services_classification.csv")
countries = pd.read_csv("/kaggle/input/new-zealand-international-trade-quarter-3-2023/country_classification.csv")
services = pd.read_csv("/kaggle/input/new-zealand-international-trade-quarter-3-2023/services_classification.csv")
goods = pd.read_csv("/kaggle/input/new-zealand-international-trade-quarter-3-2023/goods_classification.csv")

# %%
df=df.merge(countries)

# %%
df=df.drop(columns='country_code')

# %%
df=df.rename(columns={'country_label':'country'})

# %%
df
# Out:
#          time_ref  account   code product_type         value status  \
# 0          202309  Exports     00        Goods  4.865000e+03      F
# 1          202309  Exports     88        Goods  4.865000e+03      F
# 2          202309  Exports   8804        Goods  4.865000e+03      F
# 3          202309  Exports    A12     Services           NaN      C
# 4          202309  Exports  A1204     Services  8.272900e+04      F
# ...           ...      ...    ...          ...           ...    ...
# 2168915    201506  Imports     XX        Goods  1.164551e+10      F
# 2168916    201503  Imports     XX        Goods  1.107222e+10      F
# 2168917    201412  Imports     XX        Goods  1.313562e+10      F
# 2168918    201409  Imports     XX        Goods  1.296139e+10      F
# 2168919    201406  Imports     XX        Goods  1.158512e+10      F
#
#                               country
# 0                             Andorra
# 1                             Andorra
# ...

# %%
df['month'] = pd.to_datetime(df['time_ref'],format='%Y%m', errors='coerce').dt.to_period('m')

# %%
df
# Out:
#          time_ref  account   code product_type         value status  \
# 0          202309  Exports     00        Goods  4.865000e+03      F
# 1          202309  Exports     88        Goods  4.865000e+03      F
# 2          202309  Exports   8804        Goods  4.865000e+03      F
# 3          202309  Exports    A12     Services           NaN      C
# 4          202309  Exports  A1204     Services  8.272900e+04      F
# ...           ...      ...    ...          ...           ...    ...
# 2168915    201506  Imports     XX        Goods  1.164551e+10      F
# 2168916    201503  Imports     XX        Goods  1.107222e+10      F
# 2168917    201412  Imports     XX        Goods  1.313562e+10      F
# 2168918    201409  Imports     XX        Goods  1.296139e+10      F
# 2168919    201406  Imports     XX        Goods  1.158512e+10      F
#
#                               country    month
# 0                             Andorra  2023-09
# 1                             Andorra  2023-09
# ...

# %%
import plotly.express as px
fig = px.sunburst(
    df,
    path=['account','product_type','status','country'], 
    color='account', color_discrete_map={'1':'gold', '0':'darkblue'},
    width=1200, height=1200
)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...
